# %% [markdown]
# # EquiSite Inference
#
# Quick notebook workflow for running per-residue DNA/RNA binding inference from a PDB file.

# %%
from pathlib import Path

import torch

from equisite.model import EquiSitePipeline

# %%
pdb_path = Path("../examples/3HXQ-protein.pdb")
binding_type = "DNA"  # or "RNA"
device = "cuda" if torch.cuda.is_available() else "cpu"

pdb_path
# Out:
# PosixPath('../examples/3HXQ-protein.pdb')

# %%
pipeline = EquiSitePipeline.from_pretrained(
    binding_type=binding_type,
    device=device,
)
pipeline

# %%
result = pipeline.predict_proba(pdb_path)
top_rows = sorted(result, key=lambda row: row["binding_probability"], reverse=True)[:10]
top_rows
# Out:
# Loading ESM-2 (esm2_t33_650M_UR50D) ...
# ESM-2 ready.
# [{'residue_index': 636,
#   'chain': 'A',
#   'insertion_code': '',
#   'residue_name': 'ARG',
#   'binding_probability': 0.889777},
#  {'residue_index': 632,
#   'chain': 'A',
#   'insertion_code': '',
#   'residue_name': 'ARG',
#   'binding_probability': 0.882131},
#  {'residue_index': 603,
#   'chain': 'A',
#   'insertion_code': '',
#   'residue_name': 'PHE',
#   'binding_probability': 0.875927},
#  {'residue_index': 629,
#   'chain': 'A',
#   'insertion_code': '',
#   'residue_name': 'ARG',
#   'binding_probability': 0.868807},
#  {'residue_index': 628,
#   'chain': 'A',
#   'insertion_code': '',
#   'residue_name': 'GLN',
#   'binding_probability': 0.84461},
#  {'residue_index': 660,
#   'chain': 'A',
#   'insertion_code': '',
#   'residue_name': 'LYS',
#   'binding_probability': 0.832368},
#  {'residue_index': 599,
#   'chain': 'A',
#   'insertion_code': '',
#   'residue_name': 'LYS',
#   'binding_probability': 0.83084},
#  {'residue_index': 633,
#   'chain': 'A',
#   'insertion_code': '',
#   'residue_name': 'ASN',
#   'binding_probability': 0.817463},
#  {'residue_index': 637,
#   'chain': 'A',
#   'insertion_code': '',
#   'residue_name': 'TYR',
#   'binding_probability': 0.814766},
#  {'residue_index': 607,
#   'chain': 'A',
#   'insertion_code': '',
#   'residue_name': 'SER',
#   'binding_probability': 0.799443}]

# %%
output_dir = Path("../examples/notebook_outputs")
output_dir.mkdir(parents=True, exist_ok=True)

result.to_csv(output_dir / f"{pdb_path.stem}_predictions.csv")
result.to_json(output_dir / f"{pdb_path.stem}_predictions.json")

output_dir
# Out:
# PosixPath('../examples/notebook_outputs')
